# %%
import joblib

sgd_ppl_clf = joblib.load('/content/learned_model.pkl')

new_text = 'К писательнице Нине Катерли пришли с обыском из-за спектакля ее внучки Жени Беркович. Режиссера подозревают в оправдании терроризма'
predicted_label = sgd_ppl_clf.predict([new_text])[0]
print('Predicted label:', predicted_label)
# Out:
# Predicted label: Культура

# %%
# !pip install feedparser
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting feedparser
#   Downloading feedparser-6.0.10-py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.1/81.1 kB 3.2 MB/s eta 0:00:00
# Collecting sgmllib3k (from feedparser)
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: sgmllib3k
#   Building wheel for sgmllib3k (setup.py) ... done
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6046 sha256=68a966894f283d5d7e5659de36f61a582238da7e3f94a73f83758c7412f06e2c
#   Stored in directory: /root/.cache/pip/wheels/f0/69/93/a47e9d621be168e9e33c7ce60524393c0b92ae83cf6c6e89c5
# Successfully built sgmllib3k
# Installing collected packages: sgmllib3k, feedparser
# Successfully installed feedparser-6.0.10 sgmllib3k-1.0.0

# %%
import feedparser

parseList = ["https://news.mail.ru/rss/economics/91/", "https://news.mail.ru/rss/politics/91/"]
parsedList = []
count = 0

import joblib


sgd_ppl_clf = joblib.load('/content/learned_model.pkl')


for feed in parseList:
    feed = feedparser.parse(feed)
    for entry in feed.entries:
      if len(entry.summary) != 0:
        pass
      else:
        parsedList.append(entry.summary)
o = 0
ecoList = []
culList = []
sportList = []
sciList = []
for i in parsedList:
  new_text = parsedList[o]
  predicted_label = sgd_ppl_clf.predict([new_text])[0]
  if predicted_label == 'Экономика':
    ecoList.append(new_text)
  if predicted_label == 'Культура':
    culList.append(new_text)
  if predicted_label == 'Спорт':
    sportList.append(new_text)
  if predicted_label == 'Наука и техника':
    sciList.append(new_text)
  print('Predicted label:'+predicted_label+parsedList[o])
  o += 1
print(ecoList)
print(culList)
print(sportList)
print(sciList)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/feedparser/util.py in __getattr__(self, key)
#     155         try:
# --> 156             return self.__getitem__(key)
#     157         except KeyError:
#
# /usr/local/lib/python3.10/dist-packages/feedparser/util.py in __getitem__(self, key)
#     112                 return dict.__getitem__(self, realkey)
# --> 113         return dict.__getitem__(self, key)
#     114
#
# KeyError: 'summary'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-068dae3e21a9> in <cell line: 13>()
#      14     feed = feedparser.parse(feed)
#      15     for entry in feed.entries:
# ---> 16       if len(entry.summary) != 0:
#      17         pass
#      18       else:
#
# /usr/local/lib/python3.10/dist-packages/feedparser/util.py in __getattr__(self, key)
#     156             return self.__getitem__(key)
#     157         except KeyError:
# --> 158             raise AttributeError("object has no attribute '%s'" % key)
#     159
#     160     def __hash__(self):
#
# AttributeError: object has no attribute 'summary'

# %%
import feedparser

parseList = ["https://news.mail.ru/rss/economics/91/", "https://news.mail.ru/rss/politics/91/"]
parsedList = []
count = 0

for feed in parseList:
    feed = feedparser.parse(feed)
    for entry in feed.entries:
      if 'summary' in entry:
        parsedList.append(entry.summary)
        print(entry.summary_detail.value)
        print(entry.summary)
        print(entry.keys())
        print(entry.link)
        print(entry.title)
# Out:
# Премьер-министр России Михаил Мишустин дал поручения по итогам стратегической сессии по развитию промышленности, сообщили в пресс-службе кабмина. В частности, председатель правительства поручил Минэкономразвития до 20 июля проанализировать механизмы поддержки промышленности и представить предложения по их улучшению.
# Премьер-министр России Михаил Мишустин дал поручения по итогам стратегической сессии по развитию промышленности, сообщили в пресс-службе кабмина. В частности, председатель правительства поручил Минэкономразвития до 20 июля проанализировать механизмы поддержки промышленности и представить предложения по их улучшению.
# dict_keys(['amplink', 'tags', 'summary', 'summary_detail', 'id', 'guidislink', 'links', 'link', 'published', 'published_parsed', 'title', 'title_detail'])
# https://news.mail.ru/economics/

# dict_keys(['amplink', 'tags', 'summary', 'summary_detail', 'id', 'guidislink', 'links', 'link', 'published', 'published_parsed', 'title', 'title_detail'])
# https://news.mail.ru/politics/56289292/
# Польша призвала Зеленского извиниться за Волынскую резню
# Израиль поддерживает позицию Украины и западных государств, но «морально», так как не может игнорировать роль России на Ближнем Востоке, заявил глава МИД страны Эли Коэн.
# Израиль поддерживает позицию Украины и западных государств, но «морально», так как не может игнорировать роль России на Ближнем Востоке, заявил глава МИД страны Эли Коэн.
# dict_keys(['amplink', 'tags', 'summary', 'summary_detail', 'id', 'guidislink', 'links', 'link', 'published', 'published_parsed', 'title', 'title_detail'])
# https://news.mail.ru/politics/56288125/
# Израиль заявил о «моральной» поддержке Украины и учете влияния России
# ВАШИНГТОН, 20 мая — РИА Новости. США в вопросе поставок истребителей F-16 исходят из того, что не поддерживают атаки Киева по целям на российской территории, заявил помощник президента по нацбезопасности Джейк Салливан.
# ВАШИНГТОН, 20 мая — РИА Новости. США в вопросе поставок истребителей F-16 исходят из того, что не поддерживают атаки Киева по целям на российской территории, заявил помощник президента по нацбезопасности Джейк Салливан.
# dict_keys(['tags', 'summary', 'summary_detail', 'id', 'guidislink', 'links', 'link', 'published', 'published_parsed', 'title', 'title_detail'])
# https://news.mail.ru/politics/56287688/
# США заявили, что не поддерживают удары Украины по российской территории
# ВАШИНГТОН, 20 мая — РИА Новости. Формирующиеся экономики в мире осознают вред, который наносит политика Вашингтона их жизненным интересам, и отвернутся от него, заявил в пятницу посол РФ в США Анатолий Антонов, комментируя новую волну антироссийских санкций.
# ВАШИНГТОН, 20 мая — РИА Новости. Формирующиеся экономики в мире осознают вред, который наносит политика Вашингтона их жизненным интересам, и отвернутся от него, заявил в пятницу посол РФ в США Анатолий Антонов, комментируя новую волну антироссийских санкций.
# dict_keys(['tags', 'summary', 'summary_detail', 'id', 'guidislink', 'links', 'link', 'published', 'published_parsed', 'title', 'title_detail'])
# https://news.mail.ru/politics/56287316/
# Посол Антонов предрек США международное одиночество
# В новом пакете санкций США ввели обязательство для американских лиц отчитываться о наличии у них активов ЦБ и Минфина России. Ранее такое требование ввел ЕС. Также введен запрет на оказание России архитектурных и инженерных услуг.
# В новом пакете санкций США ввели обязательство для американских лиц отчитываться о наличии у них активов ЦБ и Минфина России. Ранее такое требование ввел ЕС. Также введен запрет на оказание России архитектурных и инженерных услуг.
# dict_keys(['amplink', 'tags', 'summary', 'summary_detail', 'id', 'guidislink', 'links', 'link', 'published', 'published_parsed', 'title', 'title_detail'])
# https://news.mail.ru/politics/56287394/
# США обязали американцев отчитаться об активах Банка России
# Соединенные Штаты планируют экстренно поставить на Тайвань переносные зенитно-ракетные комплексы (ПЗРК) Stinger в рамках пакета безвозмездной помощи. Об этом сообщила газета South China Morning Post (SCMP) со ссылкой на информированный источник.
# Соединенные Штаты планируют экстренно поставить на Тайвань переносные зенитно-ракетные комплексы (ПЗРК) Stinger в рамках пакета безвозмездной помощи. Об этом сообщила газета South China Morning Post (SCMP) со ссылкой на информированный источник.
# dict_keys(['amplink', 'tags', 'summary', 'summary_detail', 'id', 'guidislink', 'links', 'link', 'published', 'published_parsed', 'title', 'title_detail'])
# https://news.mail.ru/politics/56287058/
# США бесплатно передадут Тайваню комплексы Javelin и Stinger
# Президент Молдавии Майя Санду убеждена, что партнерство с СНГ невыгодно для граждан республики. Об этом она заявила в эфире телеканала Moldova 1.
# Президент Молдавии Майя Санду убеждена, что партнерство с СНГ невыгодно для граждан республики. Об этом она заявила в эфире телеканала Moldova 1.
# dict_keys(['amplink', 'tags', 'summary', 'summary_detail', 'id', 'guidislink', 'links', 'link', 'published', 'published_parsed', 'title', 'title_detail'])
# https://news.mail.ru/politics/56286298/
# Молдавия назвала невыгодным партнерство с СНГ
