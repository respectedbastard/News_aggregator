# %%
# !pip install feedparser
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.1/81.1 kB 4.3 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6046 sha256=025c1b7f774a8e636b4b61b6cb3256cd8d34144c0518c56dd4133d3e6223d6dd
#   Stored in directory: /root/.cache/pip/wheels/f0/69/93/a47e9d621be168e9e33c7ce60524393c0b92ae83cf6c6e89c5
# Successfully built sgmllib3k
# ...

# %%
import feedparser
#Ключи парсера (.keys()): dict_keys(['bozo', 'entries', 'feed', 'headers', 'href', 'status', 'encoding', 'version', 'namespaces'])
feed = feedparser.parse("https://news.mail.ru/rss/incident/91/")
#print(len(feed.entries))
'''for entry in feed.entries:
  print(entry)'''
print(feed.entries[0].keys())
for entry in feed.entries:
  print(entry.summary)
# Out:
# dict_keys(['tags', 'summary', 'summary_detail', 'id', 'guidislink', 'links', 'link', 'published', 'published_parsed', 'title', 'title_detail'])
# МОСКВА, 5 мая — РИА Новости. Российская авиация нанесла удар по пункту дислокации иностранных инструкторов украинских войск в Черниговской области, сообщил РИА Новости начальник пресс-центра группировки «Запад» Сергей Зыбинский.
# Командование Воздушных сил ВСУ сообщило, что сегодня, 4 мая, около 20:00 в Киевской области потерял управление турецкий БПЛА Bayraktar TB2. Предположительно, причиной стала техническая неисправность. Дрон было решено сбить, никто не пострадал.
# МЕЛИТОПОЛЬ, 4 мая. /ТАСС/. Вероятный прорыв дамбы из-за рекордно высокого уровня воды в Каховском водохранилище вызовет затопление территории Запорожской АЭС. Об этом заявил ТАСС в четверг советник гендиректора концерна «Росэнергоатом» Ренат Карчаа.
# ...

# %%
import feedparser

feedlist = ["https://news.mail.ru/rss/economics/91/"]
mass = []
i = 0
for feed in feedlist:
  feed = feedparser.parse(feed)
  for entry in feed.entries:
    print(entry.summary)
    mass.append(entry.summary)
    print(mass[i])
    i+=1

# %%
import feedparser

parseList = ["https://news.mail.ru/rss/economics/91/", "https://news.mail.ru/rss/politics/91/"]


#def parse_news(parseList):
for feed in parseList:
    feed = feedparser.parse(feed)
    for entry in feed.entries:
        print(entry.summary)
# Out:
# ВАШИНГТОН, 15 мая — РИА Новости. Глава Минфина США Джанет Йеллен подтвердила оценочную дату дефолта 1 июня и призвала конгресс незамедлительно повысить потолок госдолга. Об этом говорится в письме министра в адрес законодателей.
# МОСКВА, 15 мая — РИА Новости. Федеральная налоговая служба (ФНС) России не подтверждает приостановку операций по счетам ни в одной из действующих организаций, связанных с Валентином Юдашкиным, сообщили РИА Новости в пресс-службе ведомства.
# Экономисты ждут ослабления рубля в ближайший месяц. Процесс не остановит даже налоговый период. На минувшей неделе национальная валюта существенно укрепилась. В моменте доллар торговался ниже 76 ₽ — на таких отметках последний раз американская валюта была в середине марта. В ЦБ объясняли: динамика курса связана с тем, что у России растет экспорт. После существенных ограничений на поставки, в том числе энергоресурсов, ситуация якобы стала налаживаться, что позволило увеличить приток валюты в страну.
# ...

# %%
print(listForParse[0])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-d6c31d9019fa> in <cell line: 1>()
# ----> 1 print(listForParse[0])
#
# IndexError: list index out of range

# %%
def parser()
